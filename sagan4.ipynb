# %% [markdown]
# # Introduction
#
# This notebook presents **SAGAN: Self-Attention GAN** implementation as the final project of the "Introduction to Deep Learning" course in the MSDS program.
#
# Within the MSDS course, there was another project focused on CycleGAN, and I really enjoyed working on that project.
#
# Because of that experience, I decided to take on **SAGAN** for this final project --- building upon what I learned from CycleGAN while also exploring the Attention mechanism, which has become an essential part of many modern deep learning applications.
#
# SAGAN not only incorporates the Attention mechanism, but also implements important and fascinating techniques such as **pointwise convolution** and **spectral normalization**.
#
# Although fully understanding these technique is no easy task, I am determined to grasp them firmly through hands-on implementation.
#
# The ultimate goal of the notebook is to generate **handwritten digit images similar to MNIST** using SAGAN.
#
# To reduce computational cost, I will focus only on images labeled as '7' and '8' from the MNIST dataset.

# %% [markdown]
# # Download the MNIST

# %%
# For loading data

import os
import urllib.request
import zipfile
import tarfile

import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
import numpy as np

# For SAGAN implementation
import random
import math
import time
import pandas as pd
import numpy as np
from PIL import Image
from tqdm import tqdm

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torchvision import transforms

# %%
# prepare a directory
data_dir = './data/'
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
from sklearn.datasets import fetch_openml

# downloadinig the famous MNIST(28×28=784)
# option:
# as_frame=False: loading data in NumPy array format; we want this because we handle image data rather than table data
# as_frame=True : loading data in pandas DataFrame format
mnist = fetch_openml('mnist_784', version=1, data_home='./data/', as_frame=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
# Fetching data
X = mnist.data
y = mnist.target

# %%
# Visualizing the first one in our dataset
plt.imshow(X[0].reshape(28,28), cmap='gray')
print('The label of this image is "{}".'.format(y[0]))
# Out:
# The label of this image is "5".

# %%
# adding another directory
data_dir_path = "./data/img_78/"
if not os.path.exists(data_dir_path):
    os.mkdir(data_dir_path)

# %%
# saving "7" and "8" images into a directory "img_78"
count7 = 0
count8 = 0
max_num = 200  # 200 images each

for i in range(len(X)):

    # saving '7' images into the directory 
    if (y[i] == "7") and (count7<max_num):
        file_path = "./data/img_78/img_7_"+str(count7)+".jpg"
        im_f = (X[i].reshape(28, 28))  # transform the image into the shape 28x28
        pil_img_f = Image.fromarray(im_f.astype(np.uint8))  # image to PIL format
        # SAGAN will generate 64x64 image, thus the training data is adjusted accordingly.
        # BICUBIC: image interpolation method which is the best among interpolation methods {Nearest neighbor, BiLinear, BiCubic}
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)
        pil_img_f.save(file_path)
        count7 += 1

    # saving '8' images
    if (y[i] == '8') and (count8<max_num):
        file_path = "./data/img_78/img_8_"+str(count8)+".jpg"
        im_f=(X[i].reshape(28, 28))  # transforming the image into shape 28x28
        pil_img_f = Image.fromarray(im_f.astype(np.uint8)) # transforming data type to integer
        pil_img_f = pil_img_f.resize((64, 64), Image.BICUBIC)  # expand to 64x64
        pil_img_f.save(file_path)
        count8 += 1

# %%
# Setup seeds
torch.manual_seed(42)
np.random.seed(42)
random.seed(42)

# %% [markdown]
# # SAGAN Module

# %% [markdown]
# ![SAGANFig.png](attachment:1fd04a79-d499-4ebf-953d-fdd9298f3e9d.png)
# The figure is excerpted from the Self-Attention GAN paper.
#
# If we replace $f(x)$ with "key", $g(x)$ with "query", and $h(x)$ with "value" in the figure, we can see that this is exactly the same attention mechanism found in papers such as Transformer.
#
# The formula for the Scaled Dot-Product Attention used in Transformer,
# $$Attention(Q, K, V) = softmax(\frac{QK^T}{\sqrt D})V$$
#
# is directly represented in the figure.
#
# Resource:
# Self-Attention Generative Adversarial Networks
# arXiv:1805.08318

# %% [markdown]
# # Differences between Self Attention and Cross Attention
#
# The transformer architecture includes both **Self Attention** and **Cross Attention** mechanisms.
# Some models, such as BERT and SAGAN, only use Self Attention, but here we will briefly clarify the differences between the two.
#
# ### Self Attention
# Self Attention is a mechanism that compares different parts within the same input data to capture relationships.
# In the case of images, it calculates how much one pixel (or patch) relates to other pixels within the same features.
# Because it refers to itself within the same state, it is called Self Attention.

# %% [markdown]
# ![selfAttention.jpg](attachment:d0968639-c122-4733-af54-11c42c2cc197.jpg)

# %% [markdown]
# ### Cross Attention
# Cross Attention, on the other hand, compares different data sources.
# For example, in the Transformer architecture, Cross Attention is used when the Decoder refers to the features extracted by the Encoder.
# More specifically, the Encoder uses Self Attention to extract features from the input data, and the Decoder uses those features, along with the model's own previous outputs, to make predictions and generates outputs.
#
# ### Common Point
# Both Self Attention and Cross Attention share the same core computation:
# They both calculate the inner product between Query and Key.

# %%
class Self_Attention(nn.Module):
    """Self Attention Layer"""

    def __init__(self, in_dim):
        super(Self_Attention, self).__init__()

        # Pointwise Convolution
        # (explained in the Markdown cell below)
        self.query_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.key_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim//8, kernel_size=1)
        self.value_conv = nn.Conv2d(
            in_channels=in_dim, out_channels=in_dim, kernel_size=1)
            
        # softmax scaling for the attention map
        # S = q^T k -> shape: (N_query, N_key)
        # Softmax(dim=-2) applies softmax along the 2nd-to-last dimension
        # which is query axis in this case.
        # Example attention map after applying softmax;
        #          key_1 key_2 key_3
        # query_1   0.5   0.3   0.2
        # query_2   0.2   0.7   0.1
        # query_3   0.4   0.1   0.5
        self.softmax = nn.Softmax(dim=-2)
    
        # gamma: hyperparameter coefficient for self attention map. 
        # output = x + gamma * o
        # If gamma = 0, there is no effect of self attention.
        # If gamma = 1, the output of self attention is added as is.
        # If gamma > 1, the weight of self attention has more effect.
        # Through the training, model will learn how much weight it should apply on self attention.
        # default setting: gamma = 0
    
        # nn.Parameter() defines a learnable paramete in neural network.
        # Since gamma is a scalar coefficient, we initialize it as a tensor with a single element (1).
        self.gamma = nn.Parameter(torch.zeros(1))

    def forward(self, x):
        X = x
    
        # convolute, then reshape: view() is a reshape function for tensor
        # reshaping query size from [B, C, H, W] to [B, C, N] where N = HxW
        proj_query = self.query_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3]) # [Batch_size, Channel, N]
        # transposing proj_query
        proj_query = proj_query.permute(0, 2, 1) # [B, N, C]
        # key as same as query
        proj_key = self.key_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3]) # [B, C, N]
    
        # bmm(): batch matrix multiplication; multiplying matrix in each batch
        S = torch.bmm(proj_query, proj_key)
    
        # normalizing the attention to [0, 1] range
        # attention_map = self.softmax(S) 
        attention_map_T = self.softmax(S)  # 行i(Query)方向の和を1にするｿﾌﾄﾏｯｸｽ
        attention_map = attention_map_T.permute(0,2,1)  # 転置を取る
        
        # deriving self attention map
        proj_value = self.value_conv(X).view(
            X.shape[0], -1, X.shape[2]*X.shape[3]) # [B,C,H,W]->[B,C,N]
        o = torch.bmm(proj_value, attention_map.permute(
                      0, 2, 1))
    
        # reshape o: self attention map to the size of X tensor
        o = o.view(X.shape[0], X.shape[1], X.shape[2], X.shape[3])
        # attention being added to the input x
        # gamma scales the weight of attention
        out = x + self.gamma * o
    
        return out, attention_map

# %% [markdown]
# # Pointwise Convolution
# This technique became widely known through the paper **Network in Network**.
#
# It involves inserting a 1x1 convolution layer between standard convolution layers in a CNN.
#
# This allows for increasing or decreasing the number of channels **without changing the spatial dimentions** of the feature map.

# %% [markdown]
# ![pointwiseConv.jpg](attachment:7109e603-44f2-4bbf-8408-d664af8b51ef.jpg)

# %% [markdown]
# Reducing the number of channels while keeping the image size the same leads to two main benefits:
# - Feature compression
# - Reduced computational cost
#
# This structure is often referred to as a **bottleneck block**, and it is frequently used in optimized CNN architectures to improve efficiency.
#
# Resource:
# Network in network,
# Min Lin, Qiang Chen, Shuicheng Yan.
# arXiv:1312.4400

# %% [markdown]
# # Generator

# %% [markdown]
# ![DCGANFig.png](attachment:170a0698-2b91-4569-899f-34b162b9c706.png)
# The figure is excerpted from the DCGAN paper.
#
# The generator takes a random vector as the seed and gradually generates an image of the desired size by repeatedly applying transposed convolutions.

# %% [markdown]
# ![transposedConv.jpg](attachment:53a6fcb1-99d3-4ebb-8d25-2505f136ec28.jpg)

# %% [markdown]
# Our generator is composed of five convolutional layers, similar to the architecture shown in the figure.
#
# The key difference are that our 4th and 5th convolutional layers incorporate attention mechanisms, the input noise vector is 20-dimensional instead of 100-dimensional, and the final layer outputs a single channel instead of three.
#
# This design choice reflects our focus on generating **grayscale** and **relatively simple digit images**, allowing us to reduce computational complexity while maintaining effective learning.
#
# Resource:
# Unsupervised Representation Learning with Deep Convolutional Generative Adversarial Networks (DCGAN)
# Alec Radford & Luke Metz, Soumith Chintala
# arXiv:1511.06434

# %%
class Generator(nn.Module):
    def __init__(self, z_dim=20, image_size=64):
        super(Generator, self).__init__()

        # input size: (B:1,Ch:20,H:1,W:1)
        self.layer1 = nn.Sequential(
            # Applying Spectral Normalilzation
            # (explained in the Markdown cell below)
            # ConvTranspose2d(in_ch,out_ch,ker_size,stride,padding)
            nn.utils.spectral_norm(nn.ConvTranspose2d(z_dim, image_size * 8,
                                                      kernel_size=4, stride=1)),
            nn.BatchNorm2d(image_size * 8),
            nn.ReLU(inplace=True))

        # input size: (1,512,4,4)
        self.layer2 = nn.Sequential(
            # Adding Spectral Normalilzation
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size*8, image_size*4,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size*4),
            nn.ReLU(inplace=True))

        # input size: (1,256,8,8)
        self.layer3 = nn.Sequential(
            # Adding Spectral Normalilzation
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size*4, image_size*2,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size*2),
            nn.ReLU(inplace=True))

        # Adding Self Attention layer
        self.self_attention1 = Self_Attention(in_dim=image_size*2)
        
        # input size: (1,128,16,16)
        self.layer4 = nn.Sequential(
            # Adding Spectral Normalilzation
            nn.utils.spectral_norm(nn.ConvTranspose2d(image_size*2, image_size,
                                                      kernel_size=4, stride=2, padding=1)),
            nn.BatchNorm2d(image_size),
            nn.ReLU(inplace=True))

        # Adding Self Attention layer
        self.self_attention2 = Self_Attention(in_dim=image_size)
        
        # input size: (1,64,32,32)
        self.last = nn.Sequential(
            nn.ConvTranspose2d(image_size, 1, kernel_size=4,
                               stride=2, padding=1),
            nn.Tanh())

        # output size: (1,1,64,64)

    def forward(self, z):
        out = self.layer1(z)
        out = self.layer2(out)
        out = self.layer3(out)
        out, attention_map1 = self.self_attention1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attention2(out)
        out = self.last(out)

        return out, attention_map1, attention_map2

# %% [markdown]
# # Spectral Normalization
# Spectral Normalization standardizes the network's weight parameters (in contrast to Batch Normalization, which normalizes the input data).
#
# For a GAN to function effectively, the **Discriminator** must satisfy **Lipschitz continuity**.
#
# Lipschitz continuity means that small changes in the image lead to only small changes in the Discriminator's output.
#
# Conversely, if small changes in the input cause large, erratic changes in the output, the GAN fails to learn properly.
#
# To enforce Lipshitz continuity, Spectral Normalization divides each layer's weight parameters by their largest eigenvalue, ensuring that the input tensor to a layer does not get excessively amplified in the output tensor.
#
# #### Spectral normalization
# $$W_{SN}(W) = \frac{W}{\sigma(W)}$$
#
# #### Spectral Norm (a largest eigenvalue)
# $$\sigma(W) := \underset{||\textbf{h}||_{2}\le1}{max}||W\textbf{h}||_{2}$$
#
# #### Lipschitz constant
# $$\sigma(W) = \underset{\textbf{h}:\textbf{h}\neq0}{max}\frac{||W\textbf{h}||_{2}}{||\textbf{h}||}$$
#
# where;
# $W$: Weights matix (weights parameter)
# $\textbf{h}$: Eigen vector
# $\sigma(W)$: Lipschitz constant
#
# This ensures that the Lipschitz constant is less than or equal to 1.

# %% [markdown]
# ### Let's check how the generator is working

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

G = Generator(z_dim=20, image_size=64)

# input noise
input_z = torch.randn(1, 20)

# resize the tensor to (batch_size=1, ch=20, H=1, W=1)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)

# output a generated image
fake_images, attention_map1, attention_map2 = G(input_z)

img_transformed = fake_images[0][0].detach().numpy()
plt.imshow(img_transformed, cmap='gray')
plt.show()

# %% [markdown]
# As expected, the generator outputs a noisy image since it hasn't been trained yet (no weights have been updated).
# Still, it's working correctly in the sense that it produces output that can be passed to the discriminator.

# %% [markdown]
# # Discriminator

# %%
class Discriminator(nn.Module):
    def __init__(self, z_dim=20, image_size=64):
        super(Discriminator, self).__init__()
    
        self.layer1 = nn.Sequential(
            # Adding Spectral Normalilzation
            # Conv2d(in_ch,out_ch,ker_size,stride,padding)
            nn.utils.spectral_norm(nn.Conv2d(1, image_size, 
                                             kernel_size=4, stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))
    
        self.layer2 = nn.Sequential(
            # Adding Spectral Normalilzation
            nn.utils.spectral_norm(nn.Conv2d(image_size, image_size*2, 
                                             kernel_size=4, stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))
    
        self.layer3 = nn.Sequential(
            # Adding Spectral Normalilzation
            nn.utils.spectral_norm(nn.Conv2d(image_size*2, image_size*4,
                                             kernel_size=4, stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))
    
        # Adding Self Attention layer
        self.self_attention1 = Self_Attention(in_dim=image_size*4)
    
        self.layer4 = nn.Sequential(
            # Adding Spectral Normalilzation
            nn.utils.spectral_norm(nn.Conv2d(image_size*4, image_size*8,
                                             kernel_size=4, stride=2, padding=1)),
            nn.LeakyReLU(0.1, inplace=True))
        
        # Adding Self Attention layer
        self.self_attention2 = Self_Attention(in_dim=image_size*8)
    
        self.last = nn.Conv2d(image_size*8, 1, kernel_size=4, stride=1)
    
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        out, attention_map1 = self.self_attention1(out)
        out = self.layer4(out)
        out, attention_map2 = self.self_attention2(out)
        out = self.last(out)
    
        return out, attention_map1, attention_map2

# %% [markdown]
# ### Let's check how the discriminator is working

# %%
D = Discriminator(z_dim=20, image_size=64)

# Generating a fake image
input_z = torch.randn(1, 20)
input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
fake_images, _, _ = G(input_z)

# Feeding a fake image into D
d_out, attention_map1, attention_map2 = D(fake_images)
print('d_out', d_out)

# Normalizing D's output to [0,1] range by Sigmoid function
print(nn.Sigmoid()(d_out))
# Out:
# d_out tensor([[[[-0.0539]]]], grad_fn=<ConvolutionBackward0>)
# tensor([[[[0.4865]]]], grad_fn=<SigmoidBackward0>)

# %% [markdown]
# Output：
# d_out: -0.0539 (close to zero)
#
# This is the raw score, or logit, output by the Discriminator.
#
# When a logit close to zero is converted to a probability using the **sigmoid** function, the result is close to 0.5 (in this case, 0.4865).
#
# Since the Discriminator is untrained at this stage, it cannot yet distinguish real from fake images well -- so it tends to give probabilities around 0.5, effectively making random guesses.

# %% [markdown]
# # DataLoader

# %%
def make_datapath_list():
    """Preparing a filepath list for training and evaluating image data as well as the attention data"""
    train_img_list = list() # store an imagefile path

    for img_idx in range(200):
        img_path = './data/img_78/img_7_' + str(img_idx) + '.jpg'
        train_img_list.append(img_path)

        img_path = './data/img_78/img_8_' + str(img_idx) + '.jpg'
        train_img_list.append(img_path)

    return train_img_list

# %%
class ImageTransform():
    """Image preprocessing"""

    def __init__(self, mean, std):
        self.data_transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(mean, std)
        ])

    def __call__(self, img):
        return self.data_transform(img)

# %%
class GAN_Img_Dataset(data.Dataset):
    """Image dataset class; inherits PyTorch Dataset class"""
    
    def __init__(self, file_list, transform):
        self.file_list = file_list
        self.transform = transform

    def __len__(self):
        """return # of images"""
        return len(self.file_list)

    def __getitem__(self, index):
        """Obtain the preprocessed image data in Tensor format"""

        img_path = self.file_list[index]
        img = Image.open(img_path)  # [高さ][幅]白黒

        # image preprocessing
        img_transformed = self.transform(img)

        return img_transformed

# %%
# instantiating DataLoader

# preparing file list
train_img_list = make_datapath_list()

# Dataset
mean = (0.5,)
std = (0.5,)
train_dataset = GAN_Img_Dataset(
    file_list = train_img_list, transform = ImageTransform(mean, std))

# DataLoader
batch_size = 64

train_dataloader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True)

# Let's test the dataloader
batch_iterator = iter(train_dataloader)  # transform to an iterator
imges = next(batch_iterator)  # getting the first element
print(imges.size())
# Out:
# torch.Size([64, 1, 64, 64])

# %% [markdown]
# # Training

# %%
# function to train a model
def train_model(G, D, dataloader, num_epochs):
    # checking GPU availability
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    print('device', device)

    # optimizer setting
    g_lr, d_lr = 0.0001, 0.0004
    beta1, beta2 = 0.0, 0.9
    g_optimizer = torch.optim.Adam(G.parameters(), g_lr, [beta1, beta2])
    d_optimizer = torch.optim.Adam(D.parameters(), d_lr, [beta1, beta2])

    # Define loss function 
    #  -> switched to hinge version of adversarial loss
    # criterion = nn.BCEWithLogitsLoss(reduction='mean')
    
    # hyperparameters
    z_dim = 20
    mini_batch_size = 64

    # allocating the network to GPU
    G.to(device)
    D.to(device)

    G.train() # setting training mode
    D.train() # setting training mode

    # If the network is static, it can be fasten.
    torch.backends.cudnn.benchmark = True

    # number of images
    num_train_imgs = len(dataloader.dataset)
    batch_size = dataloader.batch_size

    # iteration counter
    iteration = 1
    logs = []

    # epoch loop
    for epoch in range(num_epochs):
        # measure time (start time)
        t_epoch_start = time.time()
        epoch_g_loss = 0.0 # sum of loss of an epoch
        epoch_d_loss = 0.0 # sum of loss of an epoch

        print('-------------------')
        print('Epoch {}/{}'.format(epoch, num_epochs))
        print('-------------------')
        print(' (train) ')

        # loops taking minibatches from the dataloader
        for i, images in enumerate(tqdm(dataloader, desc=f'Epoch {epoch+1}')):

            # if GPU is available:
            images = images.to(device)

            # The discriminator training
            # checking a batch size
            mini_batch_size = images.size()[0]
            # labeling '1' for real images, '0' for fake images 
            # label_real = torch.full((mini_batch_size,), 1).to(device)
            # label_fake = torch.full((mini_batch_size,), 0).to(device)

            # Let the discriminator label for 'real image'.
            d_out_real, _, _ = D(images)

            # Generating random noise `input_z` 
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            # view() means reshape the tensor.
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            # Feeding it into the generator to generate `fake image'
            fake_images, _, _ = G(input_z)
            # Let the discriminator label for 'fake image'.
            d_out_fake, _, _ = D(fake_images)

            # calculating loss for real-images and fake-images, and sum them up
            #  -> switched to hinge version of adversarial loss
            # d_loss_real = criterion(d_out_real.view(-1), label_real)
            # d_loss_fake = criterion(d_out_real.view(-1), label_fake)
            d_loss_real = torch.nn.ReLU()(1.0 - d_out_real).mean()
            # if d_out_real is greater than 1, the loss will be 0.
            d_loss_fake = torch.nn.ReLU()(1.0 + d_out_fake).mean()
            # if d_out_fake is lesser than -1, the loss will be 0.
            
            d_loss = d_loss_real + d_loss_fake
            
            # initializing gradients
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            # backpropatation
            d_loss.backward()  
            # updating parameters
            d_optimizer.step() 

            # The generator training
            input_z = torch.randn(mini_batch_size, z_dim).to(device)
            # view() means reshape the tensor
            input_z = input_z.view(input_z.size(0), input_z.size(1), 1, 1)
            # Feeding it into G to generate `fake image'
            fake_images, _, _ = G(input_z)
            # Let D label for 'fake image'.
            d_out_fake, _, _ = D(fake_images)

            # loss calculation
            g_loss = -d_out_fake.mean()

            # backpropagation
            g_optimizer.zero_grad()
            d_optimizer.zero_grad()
            g_loss.backward()
            g_optimizer.step()

            # keep record
            epoch_d_loss += d_loss.item()
            epoch_g_loss += g_loss.item()
            iteration += 1

        # The loss and accuracy rate per epoch phase
        t_epoch_finish = time.time()
        print('-------------------')
        print('epoch {} || Epoch_D_loss:{:.4f} ||Epoch_G_loss:{:.4f}'.format(
            epoch, epoch_d_loss/batch_size, epoch_g_loss/batch_size))
        print('timer: {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

    return G, D

# %% [markdown]
# These specific initialization values (in below cell) aren't backed by solid theory, but they've been shown to help in practice -- especially for GANs like DCGAN and SAGAN. So while not mandatory, they're often used to improve performance and training stability.

# %%
# Initializing network
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        # Initializing Conv2d and ConvTranspose2d
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('BatchNorm') != -1:
        # Initializing BatchNorm2d
        nn.init.normal_(m.weight.data, 1.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# executing initialization
# G.apply(weights_init)
# D.apply(weights_init)

# print('network initialization completed!')

# %%
# executing initialization
G.apply(weights_init)
D.apply(weights_init)

# Train and validate
# maybe took about 15 minutes
# num_epochs = 300
num_epochs = 170

G_update, D_update = train_model(
    G, D, dataloader = train_dataloader, num_epochs=num_epochs)
# Out:
# device cuda:0
# -------------------
# Epoch 0/170
# -------------------
#  (train)
# Epoch 1: 100%|██████████| 7/7 [00:05<00:00,  1.38it/s]
# -------------------
# epoch 0 || Epoch_D_loss:0.1500 ||Epoch_G_loss:0.0985
# timer: 5.0910 sec.
# -------------------
# Epoch 1/170
# -------------------
#  (train)
# Epoch 2: 100%|██████████| 7/7 [00:01<00:00,  6.26it/s]
# -------------------
# epoch 1 || Epoch_D_loss:0.1091 ||Epoch_G_loss:0.0529
# timer: 1.1233 sec.
# -------------------
# Epoch 2/170
# -------------------
#  (train)
# Epoch 3: 100%|██████████| 7/7 [00:01<00:00,  6.27it/s]
# -------------------
# epoch 2 || Epoch_D_loss:0.0964 ||Epoch_G_loss:0.0610
# timer: 1.1195 sec.
# -------------------
# Epoch 3/170
# -------------------
#  (train)
# Epoch 4: 100%|██████████| 7/7 [00:01<00:00,  6.33it/s]
# -------------------
# epoch 3 || Epoch_D_loss:0.1563 ||Epoch_G_loss:-0.0173
# timer: 1.1099 sec.
# -------------------
# Epoch 4/170
# -------------------
#  (train)
# Epoch 5: 100%|██████████| 7/7 [00:01<00:00,  6.36it/s]
# -------------------
# epoch 4 || Epoch_D_loss:0.0960 ||Epoch_G_loss:0.0315
# timer: 1.1060 sec.
# -------------------
# Epoch 5/170
# -------------------
#  (train)
# Epoch 6: 100%|██████████| 7/7 [00:01<00:00,  6.34it/s]
# -------------------
# epoch 5 || Epoch_D_loss:0.0467 ||Epoch_G_loss:0.1146
# timer: 1.1077 sec.
# -------------------
# Epoch 6/170
# -------------------
#  (train)
# Epoch 7: 100%|██████████| 7/7 [00:01<00:00,  6.38it/s]
# -------------------
# epoch 6 || Epoch_D_loss:0.0604 ||Epoch_G_loss:0.0771
# timer: 1.1005 sec.
# -------------------
# Epoch 7/170
# -------------------
#  (train)
# Epoch 8: 100%|██████████| 7/7 [00:01<00:00,  6.41it/s]
# -------------------
# epoch 7 || Epoch_D_loss:0.0146 ||Epoch_G_loss:0.1578
# timer: 1.0941 sec.
# -------------------
# Epoch 8/170
# -------------------
#  (train)
# Epoch 9: 100%|██████████| 7/7 [00:01<00:00,  6.46it/s]
# -------------------
# epoch 8 || Epoch_D_loss:0.0001 ||Epoch_G_loss:0.1562
# timer: 1.0862 sec.
# -------------------
# Epoch 9/170
# -------------------
#  (train)
# Epoch 10: 100%|██████████| 7/7 [00:01<00:00,  6.32it/s]
# -------------------
# epoch 9 || Epoch_D_loss:0.0683 ||Epoch_G_loss:0.1132
# timer: 1.1110 sec.
# -------------------
# Epoch 10/170
# -------------------
#  (train)
# Epoch 11: 100%|██████████| 7/7 [00:01<00:00,  6.23it/s]
# -------------------
# epoch 10 || Epoch_D_loss:0.1500 ||Epoch_G_loss:0.1055
# timer: 1.1265 sec.
# -------------------
# Epoch 11/170
# -------------------
#  (train)
# Epoch 12: 100%|██████████| 7/7 [00:01<00:00,  6.33it/s]
# -------------------
# epoch 11 || Epoch_D_loss:0.0665 ||Epoch_G_loss:0.1013
# timer: 1.1090 sec.
# -------------------
# Epoch 12/170
# -------------------
#  (train)
# Epoch 13: 100%|██████████| 7/7 [00:01<00:00,  6.41it/s]
# -------------------
# epoch 12 || Epoch_D_loss:0.0226 ||Epoch_G_loss:0.1671
# timer: 1.0952 sec.
# -------------------
# Epoch 13/170
# -------------------
#  (train)
# Epoch 14: 100%|██████████| 7/7 [00:01<00:00,  6.36it/s]
# -------------------
# epoch 13 || Epoch_D_loss:0.1087 ||Epoch_G_loss:0.0582
# timer: 1.1045 sec.
# -------------------
# Epoch 14/170
# -------------------
#  (train)
# Epoch 15: 100%|██████████| 7/7 [00:01<00:00,  6.32it/s]
# -------------------
# epoch 14 || Epoch_D_loss:0.0608 ||Epoch_G_loss:0.1313
# timer: 1.1101 sec.
# -------------------
# Epoch 15/170
# -------------------
#  (train)
# Epoch 16: 100%|██████████| 7/7 [00:01<00:00,  6.34it/s]
# -------------------
# epoch 15 || Epoch_D_loss:0.0902 ||Epoch_G_loss:0.1263
# timer: 1.1073 sec.
# -------------------
# Epoch 16/170
# -------------------
#  (train)
# Epoch 17: 100%|██████████| 7/7 [00:01<00:00,  6.34it/s]
# -------------------
# epoch 16 || Epoch_D_loss:0.0826 ||Epoch_G_loss:0.0756
# timer: 1.1065 sec.
# -------------------
# Epoch 17/170
# -------------------
#  (train)
# Epoch 18: 100%|██████████| 7/7 [00:01<00:00,  6.29it/s]
# -------------------
# epoch 17 || Epoch_D_loss:0.0722 ||Epoch_G_loss:0.1435
# timer: 1.1150 sec.
# -------------------
# Epoch 18/170
# -------------------
#  (train)
# Epoch 19: 100%|██████████| 7/7 [00:01<00:00,  6.32it/s]
# -------------------
# epoch 18 || Epoch_D_loss:0.1147 ||Epoch_G_loss:0.0585
# timer: 1.1119 sec.
# -------------------
# Epoch 19/170
# -------------------
#  (train)
# Epoch 20: 100%|██████████| 7/7 [00:01<00:00,  6.25it/s]
# -------------------
# epoch 19 || Epoch_D_loss:0.1148 ||Epoch_G_loss:0.0743
# timer: 1.1240 sec.
# -------------------
# Epoch 20/170
# -------------------
#  (train)
# Epoch 21: 100%|██████████| 7/7 [00:01<00:00,  6.28it/s]
# -------------------
# epoch 20 || Epoch_D_loss:0.1015 ||Epoch_G_loss:0.0589
# timer: 1.1165 sec.
# -------------------
# Epoch 21/170
# -------------------
#  (train)
# Epoch 22: 100%|██████████| 7/7 [00:01<00:00,  6.26it/s]
# -------------------
# epoch 21 || Epoch_D_loss:0.1096 ||Epoch_G_loss:0.1013
# timer: 1.1224 sec.
# -------------------
# Epoch 22/170
# -------------------
#  (train)
# Epoch 23: 100%|██████████| 7/7 [00:01<00:00,  6.28it/s]
# -------------------
# epoch 22 || Epoch_D_loss:0.1280 ||Epoch_G_loss:0.0668
# timer: 1.1180 sec.
# -------------------
# Epoch 23/170
# -------------------
#  (train)
# Epoch 24: 100%|██████████| 7/7 [00:01<00:00,  6.23it/s]
# -------------------
# epoch 23 || Epoch_D_loss:0.1187 ||Epoch_G_loss:0.0773
# timer: 1.1262 sec.
# -------------------
# Epoch 24/170
# -------------------
#  (train)
# Epoch 25: 100%|██████████| 7/7 [00:01<00:00,  6.19it/s]
# -------------------
# epoch 24 || Epoch_D_loss:0.1264 ||Epoch_G_loss:0.0525
# timer: 1.1345 sec.
# -------------------
# Epoch 25/170
# -------------------
#  (train)
# Epoch 26: 100%|██████████| 7/7 [00:01<00:00,  6.22it/s]
# -------------------
# epoch 25 || Epoch_D_loss:0.1762 ||Epoch_G_loss:0.0270
# timer: 1.1292 sec.
# -------------------
# Epoch 26/170
# -------------------
#  (train)
# Epoch 27: 100%|██████████| 7/7 [00:01<00:00,  6.15it/s]
# -------------------
# epoch 26 || Epoch_D_loss:0.1424 ||Epoch_G_loss:0.0532
# timer: 1.1404 sec.
# -------------------
# Epoch 27/170
# -------------------
#  (train)
# Epoch 28: 100%|██████████| 7/7 [00:01<00:00,  6.19it/s]
# -------------------
# epoch 27 || Epoch_D_loss:0.1521 ||Epoch_G_loss:0.0848
# timer: 1.1331 sec.
# -------------------
# Epoch 28/170
# -------------------
#  (train)
# Epoch 29: 100%|██████████| 7/7 [00:01<00:00,  6.07it/s]
# -------------------
# epoch 28 || Epoch_D_loss:0.1714 ||Epoch_G_loss:0.0457
# timer: 1.1581 sec.
# -------------------
# Epoch 29/170
# -------------------
#  (train)
# Epoch 30: 100%|██████████| 7/7 [00:01<00:00,  6.20it/s]
# -------------------
# epoch 29 || Epoch_D_loss:0.1583 ||Epoch_G_loss:0.1035
# timer: 1.1308 sec.
# -------------------
# Epoch 30/170
# -------------------
#  (train)
# Epoch 31: 100%|██████████| 7/7 [00:01<00:00,  6.17it/s]
# -------------------
# epoch 30 || Epoch_D_loss:0.1557 ||Epoch_G_loss:0.0475
# timer: 1.1382 sec.
# -------------------
# Epoch 31/170
# -------------------
#  (train)
# Epoch 32: 100%|██████████| 7/7 [00:01<00:00,  6.17it/s]
# -------------------
# epoch 31 || Epoch_D_loss:0.1877 ||Epoch_G_loss:0.0475
# timer: 1.1371 sec.
# -------------------
# Epoch 32/170
# -------------------
#  (train)
# Epoch 33: 100%|██████████| 7/7 [00:01<00:00,  6.13it/s]
# -------------------
# epoch 32 || Epoch_D_loss:0.1843 ||Epoch_G_loss:0.0095
# timer: 1.1458 sec.
# -------------------
# Epoch 33/170
# -------------------
#  (train)
# Epoch 34: 100%|██████████| 7/7 [00:01<00:00,  6.16it/s]
# -------------------
# epoch 33 || Epoch_D_loss:0.1727 ||Epoch_G_loss:0.0299
# timer: 1.1412 sec.
# -------------------
# Epoch 34/170
# -------------------
#  (train)
# Epoch 35: 100%|██████████| 7/7 [00:01<00:00,  6.15it/s]
# -------------------
# epoch 34 || Epoch_D_loss:0.1939 ||Epoch_G_loss:0.0251
# timer: 1.1409 sec.
# -------------------
# Epoch 35/170
# -------------------
#  (train)
# Epoch 36: 100%|██████████| 7/7 [00:01<00:00,  6.12it/s]
# -------------------
# epoch 35 || Epoch_D_loss:0.1871 ||Epoch_G_loss:0.0267
# timer: 1.1462 sec.
# -------------------
# Epoch 36/170
# -------------------
#  (train)
# Epoch 37: 100%|██████████| 7/7 [00:01<00:00,  6.07it/s]
# -------------------
# epoch 36 || Epoch_D_loss:0.1840 ||Epoch_G_loss:0.0374
# timer: 1.1564 sec.
# -------------------
# Epoch 37/170
# -------------------
#  (train)
# Epoch 38: 100%|██████████| 7/7 [00:01<00:00,  6.13it/s]
# -------------------
# epoch 37 || Epoch_D_loss:0.1753 ||Epoch_G_loss:0.0531
# timer: 1.1449 sec.
# -------------------
# Epoch 38/170
# -------------------
#  (train)
# Epoch 39: 100%|██████████| 7/7 [00:01<00:00,  6.09it/s]
# -------------------
# epoch 38 || Epoch_D_loss:0.2003 ||Epoch_G_loss:-0.0061
# timer: 1.1525 sec.
# -------------------
# Epoch 39/170
# -------------------
#  (train)
# Epoch 40: 100%|██████████| 7/7 [00:01<00:00,  6.06it/s]
# -------------------
# epoch 39 || Epoch_D_loss:0.1968 ||Epoch_G_loss:0.0464
# timer: 1.1572 sec.
# -------------------
# Epoch 40/170
# -------------------
#  (train)
# Epoch 41: 100%|██████████| 7/7 [00:01<00:00,  6.11it/s]
# -------------------
# epoch 40 || Epoch_D_loss:0.1988 ||Epoch_G_loss:0.0247
# timer: 1.1490 sec.
# -------------------
# Epoch 41/170
# -------------------
#  (train)
# Epoch 42: 100%|██████████| 7/7 [00:01<00:00,  6.10it/s]
# -------------------
# epoch 41 || Epoch_D_loss:0.1912 ||Epoch_G_loss:0.0486
# timer: 1.1511 sec.
# -------------------
# Epoch 42/170
# -------------------
#  (train)
# Epoch 43: 100%|██████████| 7/7 [00:01<00:00,  6.06it/s]
# -------------------
# epoch 42 || Epoch_D_loss:0.1931 ||Epoch_G_loss:0.0232
# timer: 1.1589 sec.
# -------------------
# Epoch 43/170
# -------------------
#  (train)
# Epoch 44: 100%|██████████| 7/7 [00:01<00:00,  6.08it/s]
# -------------------
# epoch 43 || Epoch_D_loss:0.2110 ||Epoch_G_loss:0.0134
# timer: 1.1538 sec.
# -------------------
# Epoch 44/170
# -------------------
#  (train)
# Epoch 45: 100%|██████████| 7/7 [00:01<00:00,  6.11it/s]
# -------------------
# epoch 44 || Epoch_D_loss:0.1876 ||Epoch_G_loss:0.0587
# timer: 1.1484 sec.
# -------------------
# Epoch 45/170
# -------------------
#  (train)
# Epoch 46: 100%|██████████| 7/7 [00:01<00:00,  6.03it/s]
# -------------------
# epoch 45 || Epoch_D_loss:0.1950 ||Epoch_G_loss:0.0190
# timer: 1.1647 sec.
# -------------------
# Epoch 46/170
# -------------------
#  (train)
# Epoch 47: 100%|██████████| 7/7 [00:01<00:00,  6.02it/s]
# -------------------
# epoch 46 || Epoch_D_loss:0.1858 ||Epoch_G_loss:0.0691
# timer: 1.1661 sec.
# -------------------
# Epoch 47/170
# -------------------
#  (train)
# Epoch 48: 100%|██████████| 7/7 [00:01<00:00,  6.08it/s]
# -------------------
# epoch 47 || Epoch_D_loss:0.2038 ||Epoch_G_loss:0.0172
# timer: 1.1542 sec.
# -------------------
# Epoch 48/170
# -------------------
#  (train)
# Epoch 49: 100%|██████████| 7/7 [00:01<00:00,  6.07it/s]
# -------------------
# epoch 48 || Epoch_D_loss:0.1960 ||Epoch_G_loss:0.0268
# timer: 1.1556 sec.
# -------------------
# Epoch 49/170
# -------------------
#  (train)
# Epoch 50: 100%|██████████| 7/7 [00:01<00:00,  6.04it/s]
# -------------------
# epoch 49 || Epoch_D_loss:0.1869 ||Epoch_G_loss:0.0163
# timer: 1.1621 sec.
# -------------------
# Epoch 50/170
# -------------------
#  (train)
# Epoch 51: 100%|██████████| 7/7 [00:01<00:00,  6.01it/s]
# -------------------
# epoch 50 || Epoch_D_loss:0.1909 ||Epoch_G_loss:0.0278
# timer: 1.1682 sec.
# -------------------
# Epoch 51/170
# -------------------
#  (train)
# Epoch 52: 100%|██████████| 7/7 [00:01<00:00,  5.97it/s]
# -------------------
# epoch 51 || Epoch_D_loss:0.1773 ||Epoch_G_loss:0.0610
# timer: 1.1748 sec.
# -------------------
# Epoch 52/170
# -------------------
#  (train)
# Epoch 53: 100%|██████████| 7/7 [00:01<00:00,  5.96it/s]
# -------------------
# epoch 52 || Epoch_D_loss:0.2158 ||Epoch_G_loss:-0.0368
# timer: 1.1767 sec.
# -------------------
# Epoch 53/170
# -------------------
#  (train)
# Epoch 54: 100%|██████████| 7/7 [00:01<00:00,  5.99it/s]
# -------------------
# epoch 53 || Epoch_D_loss:0.1943 ||Epoch_G_loss:0.0087
# timer: 1.1720 sec.
# -------------------
# Epoch 54/170
# -------------------
#  (train)
# Epoch 55: 100%|██████████| 7/7 [00:01<00:00,  5.92it/s]
# -------------------
# epoch 54 || Epoch_D_loss:0.1792 ||Epoch_G_loss:0.0736
# timer: 1.1853 sec.
# -------------------
# Epoch 55/170
# -------------------
#  (train)
# Epoch 56: 100%|██████████| 7/7 [00:01<00:00,  5.96it/s]
# -------------------
# epoch 55 || Epoch_D_loss:0.2079 ||Epoch_G_loss:-0.0011
# timer: 1.1765 sec.
# -------------------
# Epoch 56/170
# -------------------
#  (train)
# Epoch 57: 100%|██████████| 7/7 [00:01<00:00,  5.94it/s]
# -------------------
# epoch 56 || Epoch_D_loss:0.1734 ||Epoch_G_loss:0.0451
# timer: 1.1834 sec.
# -------------------
# Epoch 57/170
# -------------------
#  (train)
# Epoch 58: 100%|██████████| 7/7 [00:01<00:00,  5.96it/s]
# -------------------
# epoch 57 || Epoch_D_loss:0.1825 ||Epoch_G_loss:0.0204
# timer: 1.1760 sec.
# -------------------
# Epoch 58/170
# -------------------
#  (train)
# Epoch 59: 100%|██████████| 7/7 [00:01<00:00,  5.96it/s]
# -------------------
# epoch 58 || Epoch_D_loss:0.1886 ||Epoch_G_loss:0.0345
# timer: 1.1783 sec.
# -------------------
# Epoch 59/170
# -------------------
#  (train)
# Epoch 60: 100%|██████████| 7/7 [00:01<00:00,  5.88it/s]
# -------------------
# epoch 59 || Epoch_D_loss:0.1748 ||Epoch_G_loss:0.0386
# timer: 1.1940 sec.
# -------------------
# Epoch 60/170
# -------------------
#  (train)
# Epoch 61: 100%|██████████| 7/7 [00:01<00:00,  5.95it/s]
# -------------------
# epoch 60 || Epoch_D_loss:0.1988 ||Epoch_G_loss:0.0302
# timer: 1.1802 sec.
# -------------------
# Epoch 61/170
# -------------------
#  (train)
# Epoch 62: 100%|██████████| 7/7 [00:01<00:00,  5.89it/s]
# -------------------
# epoch 61 || Epoch_D_loss:0.1635 ||Epoch_G_loss:0.0723
# timer: 1.1917 sec.
# -------------------
# Epoch 62/170
# -------------------
#  (train)
# Epoch 63: 100%|██████████| 7/7 [00:01<00:00,  5.84it/s]
# -------------------
# epoch 62 || Epoch_D_loss:0.1891 ||Epoch_G_loss:0.0228
# timer: 1.2012 sec.
# -------------------
# Epoch 63/170
# -------------------
#  (train)
# Epoch 64: 100%|██████████| 7/7 [00:01<00:00,  5.88it/s]
# -------------------
# epoch 63 || Epoch_D_loss:0.1853 ||Epoch_G_loss:0.0354
# timer: 1.1940 sec.
# -------------------
# Epoch 64/170
# -------------------
#  (train)
# Epoch 65: 100%|██████████| 7/7 [00:01<00:00,  5.90it/s]
# -------------------
# epoch 64 || Epoch_D_loss:0.1814 ||Epoch_G_loss:0.0293
# timer: 1.1884 sec.
# -------------------
# Epoch 65/170
# -------------------
#  (train)
# Epoch 66: 100%|██████████| 7/7 [00:01<00:00,  5.85it/s]
# -------------------
# epoch 65 || Epoch_D_loss:0.1837 ||Epoch_G_loss:0.0320
# timer: 1.1998 sec.
# -------------------
# Epoch 66/170
# -------------------
#  (train)
# Epoch 67: 100%|██████████| 7/7 [00:01<00:00,  5.83it/s]
# -------------------
# epoch 66 || Epoch_D_loss:0.1844 ||Epoch_G_loss:0.0132
# timer: 1.2047 sec.
# -------------------
# Epoch 67/170
# -------------------
#  (train)
# Epoch 68: 100%|██████████| 7/7 [00:01<00:00,  5.78it/s]
# -------------------
# epoch 67 || Epoch_D_loss:0.1772 ||Epoch_G_loss:0.0471
# timer: 1.2126 sec.
# -------------------
# Epoch 68/170
# -------------------
#  (train)
# Epoch 69: 100%|██████████| 7/7 [00:01<00:00,  5.85it/s]
# -------------------
# epoch 68 || Epoch_D_loss:0.1888 ||Epoch_G_loss:0.0367
# timer: 1.1987 sec.
# -------------------
# Epoch 69/170
# -------------------
#  (train)
# Epoch 70: 100%|██████████| 7/7 [00:01<00:00,  5.81it/s]
# -------------------
# epoch 69 || Epoch_D_loss:0.1802 ||Epoch_G_loss:0.0459
# timer: 1.2066 sec.
# -------------------
# Epoch 70/170
# -------------------
#  (train)
# Epoch 71: 100%|██████████| 7/7 [00:01<00:00,  5.76it/s]
# -------------------
# epoch 70 || Epoch_D_loss:0.1714 ||Epoch_G_loss:0.0417
# timer: 1.2205 sec.
# -------------------
# Epoch 71/170
# -------------------
#  (train)
# Epoch 72: 100%|██████████| 7/7 [00:01<00:00,  5.74it/s]
# -------------------
# epoch 71 || Epoch_D_loss:0.1723 ||Epoch_G_loss:0.0414
# timer: 1.2229 sec.
# -------------------
# Epoch 72/170
# -------------------
#  (train)
# Epoch 73: 100%|██████████| 7/7 [00:01<00:00,  5.79it/s]
# -------------------
# epoch 72 || Epoch_D_loss:0.1806 ||Epoch_G_loss:0.0251
# timer: 1.2112 sec.
# -------------------
# Epoch 73/170
# -------------------
#  (train)
# Epoch 74: 100%|██████████| 7/7 [00:01<00:00,  5.73it/s]
# -------------------
# epoch 73 || Epoch_D_loss:0.1691 ||Epoch_G_loss:0.0329
# timer: 1.2244 sec.
# -------------------
# Epoch 74/170
# -------------------
#  (train)
# Epoch 75: 100%|██████████| 7/7 [00:01<00:00,  5.76it/s]
# -------------------
# epoch 74 || Epoch_D_loss:0.1936 ||Epoch_G_loss:0.0348
# timer: 1.2199 sec.
# -------------------
# Epoch 75/170
# -------------------
#  (train)
# Epoch 76: 100%|██████████| 7/7 [00:01<00:00,  5.73it/s]
# -------------------
# epoch 75 || Epoch_D_loss:0.1835 ||Epoch_G_loss:0.0411
# timer: 1.2246 sec.
# -------------------
# Epoch 76/170
# -------------------
#  (train)
# Epoch 77: 100%|██████████| 7/7 [00:01<00:00,  5.73it/s]
# -------------------
# epoch 76 || Epoch_D_loss:0.1764 ||Epoch_G_loss:0.0423
# timer: 1.2244 sec.
# -------------------
# Epoch 77/170
# -------------------
#  (train)
# Epoch 78: 100%|██████████| 7/7 [00:01<00:00,  5.65it/s]
# -------------------
# epoch 77 || Epoch_D_loss:0.1653 ||Epoch_G_loss:0.0503
# timer: 1.2425 sec.
# -------------------
# Epoch 78/170
# -------------------
#  (train)
# Epoch 79: 100%|██████████| 7/7 [00:01<00:00,  5.70it/s]
# -------------------
# epoch 78 || Epoch_D_loss:0.1885 ||Epoch_G_loss:0.0190
# timer: 1.2320 sec.
# -------------------
# Epoch 79/170
# -------------------
#  (train)
# Epoch 80: 100%|██████████| 7/7 [00:01<00:00,  5.69it/s]
# -------------------
# epoch 79 || Epoch_D_loss:0.1686 ||Epoch_G_loss:0.0394
# timer: 1.2336 sec.
# -------------------
# Epoch 80/170
# -------------------
#  (train)
# Epoch 81: 100%|██████████| 7/7 [00:01<00:00,  5.71it/s]
# -------------------
# epoch 80 || Epoch_D_loss:0.1809 ||Epoch_G_loss:0.0397
# timer: 1.2305 sec.
# -------------------
# Epoch 81/170
# -------------------
#  (train)
# Epoch 82: 100%|██████████| 7/7 [00:01<00:00,  5.63it/s]
# -------------------
# epoch 81 || Epoch_D_loss:0.1672 ||Epoch_G_loss:0.0458
# timer: 1.2460 sec.
# -------------------
# Epoch 82/170
# -------------------
#  (train)
# Epoch 83: 100%|██████████| 7/7 [00:01<00:00,  5.63it/s]
# -------------------
# epoch 82 || Epoch_D_loss:0.1724 ||Epoch_G_loss:0.0383
# timer: 1.2472 sec.
# -------------------
# Epoch 83/170
# -------------------
#  (train)
# Epoch 84: 100%|██████████| 7/7 [00:01<00:00,  5.69it/s]
# -------------------
# epoch 83 || Epoch_D_loss:0.1773 ||Epoch_G_loss:0.0440
# timer: 1.2319 sec.
# -------------------
# Epoch 84/170
# -------------------
#  (train)
# Epoch 85: 100%|██████████| 7/7 [00:01<00:00,  5.67it/s]
# -------------------
# epoch 84 || Epoch_D_loss:0.1741 ||Epoch_G_loss:0.0385
# timer: 1.2375 sec.
# -------------------
# Epoch 85/170
# -------------------
#  (train)
# Epoch 86: 100%|██████████| 7/7 [00:01<00:00,  5.64it/s]
# -------------------
# epoch 85 || Epoch_D_loss:0.1769 ||Epoch_G_loss:0.0224
# timer: 1.2449 sec.
# -------------------
# Epoch 86/170
# -------------------
#  (train)
# Epoch 87: 100%|██████████| 7/7 [00:01<00:00,  5.59it/s]
# -------------------
# epoch 86 || Epoch_D_loss:0.1742 ||Epoch_G_loss:0.0435
# timer: 1.2553 sec.
# -------------------
# Epoch 87/170
# -------------------
#  (train)
# Epoch 88: 100%|██████████| 7/7 [00:01<00:00,  5.56it/s]
# -------------------
# epoch 87 || Epoch_D_loss:0.1631 ||Epoch_G_loss:0.0434
# timer: 1.2615 sec.
# -------------------
# Epoch 88/170
# -------------------
#  (train)
# Epoch 89: 100%|██████████| 7/7 [00:01<00:00,  5.61it/s]
# -------------------
# epoch 88 || Epoch_D_loss:0.1807 ||Epoch_G_loss:0.0412
# timer: 1.2499 sec.
# -------------------
# Epoch 89/170
# -------------------
#  (train)
# Epoch 90: 100%|██████████| 7/7 [00:01<00:00,  5.56it/s]
# -------------------
# epoch 89 || Epoch_D_loss:0.1663 ||Epoch_G_loss:0.0415
# timer: 1.2616 sec.
# -------------------
# Epoch 90/170
# -------------------
#  (train)
# Epoch 91: 100%|██████████| 7/7 [00:01<00:00,  5.59it/s]
# -------------------
# epoch 90 || Epoch_D_loss:0.1627 ||Epoch_G_loss:0.0332
# timer: 1.2564 sec.
# -------------------
# Epoch 91/170
# -------------------
#  (train)
# Epoch 92: 100%|██████████| 7/7 [00:01<00:00,  5.56it/s]
# -------------------
# epoch 91 || Epoch_D_loss:0.1689 ||Epoch_G_loss:0.0633
# timer: 1.2633 sec.
# -------------------
# Epoch 92/170
# -------------------
#  (train)
# Epoch 93: 100%|██████████| 7/7 [00:01<00:00,  5.46it/s]
# -------------------
# epoch 92 || Epoch_D_loss:0.1679 ||Epoch_G_loss:0.0467
# timer: 1.2857 sec.
# -------------------
# Epoch 93/170
# -------------------
#  (train)
# Epoch 94: 100%|██████████| 7/7 [00:01<00:00,  5.54it/s]
# -------------------
# epoch 93 || Epoch_D_loss:0.1761 ||Epoch_G_loss:0.0574
# timer: 1.2657 sec.
# -------------------
# Epoch 94/170
# -------------------
#  (train)
# Epoch 95: 100%|██████████| 7/7 [00:01<00:00,  5.51it/s]
# -------------------
# epoch 94 || Epoch_D_loss:0.1685 ||Epoch_G_loss:0.0603
# timer: 1.2739 sec.
# -------------------
# Epoch 95/170
# -------------------
#  (train)
# Epoch 96: 100%|██████████| 7/7 [00:01<00:00,  5.50it/s]
# -------------------
# epoch 95 || Epoch_D_loss:0.1593 ||Epoch_G_loss:0.0398
# timer: 1.2775 sec.
# -------------------
# Epoch 96/170
# -------------------
#  (train)
# Epoch 97: 100%|██████████| 7/7 [00:01<00:00,  5.50it/s]
# -------------------
# epoch 96 || Epoch_D_loss:0.1705 ||Epoch_G_loss:0.0419
# timer: 1.2748 sec.
# -------------------
# Epoch 97/170
# -------------------
#  (train)
# Epoch 98: 100%|██████████| 7/7 [00:01<00:00,  5.49it/s]
# -------------------
# epoch 97 || Epoch_D_loss:0.1634 ||Epoch_G_loss:0.0456
# timer: 1.2786 sec.
# -------------------
# Epoch 98/170
# -------------------
#  (train)
# Epoch 99: 100%|██████████| 7/7 [00:01<00:00,  5.47it/s]
# -------------------
# epoch 98 || Epoch_D_loss:0.1553 ||Epoch_G_loss:0.0669
# timer: 1.2815 sec.
# -------------------
# Epoch 99/170
# -------------------
#  (train)
# Epoch 100: 100%|██████████| 7/7 [00:01<00:00,  5.45it/s]
# -------------------
# epoch 99 || Epoch_D_loss:0.1729 ||Epoch_G_loss:0.0493
# timer: 1.2882 sec.
# -------------------
# Epoch 100/170
# -------------------
#  (train)
# Epoch 101: 100%|██████████| 7/7 [00:01<00:00,  5.49it/s]
# -------------------
# epoch 100 || Epoch_D_loss:0.1676 ||Epoch_G_loss:0.0427
# timer: 1.2775 sec.
# -------------------
# Epoch 101/170
# -------------------
#  (train)
# Epoch 102: 100%|██████████| 7/7 [00:01<00:00,  5.46it/s]
# -------------------
# epoch 101 || Epoch_D_loss:0.1605 ||Epoch_G_loss:0.0827
# timer: 1.2859 sec.
# -------------------
# Epoch 102/170
# -------------------
#  (train)
# Epoch 103: 100%|██████████| 7/7 [00:01<00:00,  5.40it/s]
# -------------------
# epoch 102 || Epoch_D_loss:0.1593 ||Epoch_G_loss:0.0492
# timer: 1.3003 sec.
# -------------------
# Epoch 103/170
# -------------------
#  (train)
# Epoch 104: 100%|██████████| 7/7 [00:01<00:00,  5.40it/s]
# -------------------
# epoch 103 || Epoch_D_loss:0.1500 ||Epoch_G_loss:0.0460
# timer: 1.2988 sec.
# -------------------
# Epoch 104/170
# -------------------
#  (train)
# Epoch 105: 100%|██████████| 7/7 [00:01<00:00,  5.45it/s]
# -------------------
# epoch 104 || Epoch_D_loss:0.1517 ||Epoch_G_loss:0.0617
# timer: 1.2881 sec.
# -------------------
# Epoch 105/170
# -------------------
#  (train)
# Epoch 106: 100%|██████████| 7/7 [00:01<00:00,  5.41it/s]
# -------------------
# epoch 105 || Epoch_D_loss:0.1720 ||Epoch_G_loss:0.0877
# timer: 1.2969 sec.
# -------------------
# Epoch 106/170
# -------------------
#  (train)
# Epoch 107: 100%|██████████| 7/7 [00:01<00:00,  5.35it/s]
# -------------------
# epoch 106 || Epoch_D_loss:0.1559 ||Epoch_G_loss:0.0274
# timer: 1.3141 sec.
# -------------------
# Epoch 107/170
# -------------------
#  (train)
# Epoch 108: 100%|██████████| 7/7 [00:01<00:00,  5.28it/s]
# -------------------
# epoch 107 || Epoch_D_loss:0.1502 ||Epoch_G_loss:0.0682
# timer: 1.3290 sec.
# -------------------
# Epoch 108/170
# -------------------
#  (train)
# Epoch 109: 100%|██████████| 7/7 [00:01<00:00,  5.36it/s]
# -------------------
# epoch 108 || Epoch_D_loss:0.1607 ||Epoch_G_loss:0.0367
# timer: 1.3115 sec.
# -------------------
# Epoch 109/170
# -------------------
#  (train)
# Epoch 110: 100%|██████████| 7/7 [00:01<00:00,  5.26it/s]
# -------------------
# epoch 109 || Epoch_D_loss:0.1523 ||Epoch_G_loss:0.0498
# timer: 1.3340 sec.
# -------------------
# Epoch 110/170
# -------------------
#  (train)
# Epoch 111: 100%|██████████| 7/7 [00:01<00:00,  5.32it/s]
# -------------------
# epoch 110 || Epoch_D_loss:0.1505 ||Epoch_G_loss:0.0568
# timer: 1.3186 sec.
# -------------------
# Epoch 111/170
# -------------------
#  (train)
# Epoch 112: 100%|██████████| 7/7 [00:01<00:00,  5.28it/s]
# -------------------
# epoch 111 || Epoch_D_loss:0.1539 ||Epoch_G_loss:0.0519
# timer: 1.3278 sec.
# -------------------
# Epoch 112/170
# -------------------
#  (train)
# Epoch 113: 100%|██████████| 7/7 [00:01<00:00,  5.24it/s]
# -------------------
# epoch 112 || Epoch_D_loss:0.1599 ||Epoch_G_loss:0.0653
# timer: 1.3394 sec.
# -------------------
# Epoch 113/170
# -------------------
#  (train)
# Epoch 114: 100%|██████████| 7/7 [00:01<00:00,  5.32it/s]
# -------------------
# epoch 113 || Epoch_D_loss:0.1531 ||Epoch_G_loss:0.0546
# timer: 1.3180 sec.
# -------------------
# Epoch 114/170
# -------------------
#  (train)
# Epoch 115: 100%|██████████| 7/7 [00:01<00:00,  5.21it/s]
# -------------------
# epoch 114 || Epoch_D_loss:0.1453 ||Epoch_G_loss:0.0727
# timer: 1.3475 sec.
# -------------------
# Epoch 115/170
# -------------------
#  (train)
# Epoch 116: 100%|██████████| 7/7 [00:01<00:00,  5.19it/s]
# -------------------
# epoch 115 || Epoch_D_loss:0.1489 ||Epoch_G_loss:0.0645
# timer: 1.3516 sec.
# -------------------
# Epoch 116/170
# -------------------
#  (train)
# Epoch 117: 100%|██████████| 7/7 [00:01<00:00,  5.20it/s]
# -------------------
# epoch 116 || Epoch_D_loss:0.1513 ||Epoch_G_loss:0.0655
# timer: 1.3494 sec.
# -------------------
# Epoch 117/170
# -------------------
#  (train)
# Epoch 118: 100%|██████████| 7/7 [00:01<00:00,  5.19it/s]
# -------------------
# epoch 117 || Epoch_D_loss:0.1494 ||Epoch_G_loss:0.0599
# timer: 1.3522 sec.
# -------------------
# Epoch 118/170
# -------------------
#  (train)
# Epoch 119: 100%|██████████| 7/7 [00:01<00:00,  5.16it/s]
# -------------------
# epoch 118 || Epoch_D_loss:0.1411 ||Epoch_G_loss:0.0704
# timer: 1.3589 sec.
# -------------------
# Epoch 119/170
# -------------------
#  (train)
# Epoch 120: 100%|██████████| 7/7 [00:01<00:00,  5.16it/s]
# -------------------
# epoch 119 || Epoch_D_loss:0.1462 ||Epoch_G_loss:0.0618
# timer: 1.3585 sec.
# -------------------
# Epoch 120/170
# -------------------
#  (train)
# Epoch 121: 100%|██████████| 7/7 [00:01<00:00,  5.16it/s]
# -------------------
# epoch 120 || Epoch_D_loss:0.1361 ||Epoch_G_loss:0.0695
# timer: 1.3605 sec.
# -------------------
# Epoch 121/170
# -------------------
#  (train)
# Epoch 122: 100%|██████████| 7/7 [00:01<00:00,  5.13it/s]
# -------------------
# epoch 121 || Epoch_D_loss:0.1448 ||Epoch_G_loss:0.0405
# timer: 1.3673 sec.
# -------------------
# Epoch 122/170
# -------------------
#  (train)
# Epoch 123: 100%|██████████| 7/7 [00:01<00:00,  5.11it/s]
# -------------------
# epoch 122 || Epoch_D_loss:0.1266 ||Epoch_G_loss:0.0714
# timer: 1.3724 sec.
# -------------------
# Epoch 123/170
# -------------------
#  (train)
# Epoch 124: 100%|██████████| 7/7 [00:01<00:00,  5.10it/s]
# -------------------
# epoch 123 || Epoch_D_loss:0.1573 ||Epoch_G_loss:0.0712
# timer: 1.3765 sec.
# -------------------
# Epoch 124/170
# -------------------
#  (train)
# Epoch 125: 100%|██████████| 7/7 [00:01<00:00,  5.14it/s]
# -------------------
# epoch 124 || Epoch_D_loss:0.1487 ||Epoch_G_loss:0.0724
# timer: 1.3644 sec.
# -------------------
# Epoch 125/170
# -------------------
#  (train)
# Epoch 126: 100%|██████████| 7/7 [00:01<00:00,  5.10it/s]
# -------------------
# epoch 125 || Epoch_D_loss:0.1387 ||Epoch_G_loss:0.0593
# timer: 1.3769 sec.
# -------------------
# Epoch 126/170
# -------------------
#  (train)
# Epoch 127: 100%|██████████| 7/7 [00:01<00:00,  5.11it/s]
# -------------------
# epoch 126 || Epoch_D_loss:0.1380 ||Epoch_G_loss:0.0723
# timer: 1.3716 sec.
# -------------------
# Epoch 127/170
# -------------------
#  (train)
# Epoch 128: 100%|██████████| 7/7 [00:01<00:00,  5.10it/s]
# -------------------
# epoch 127 || Epoch_D_loss:0.1377 ||Epoch_G_loss:0.0618
# timer: 1.3746 sec.
# -------------------
# Epoch 128/170
# -------------------
#  (train)
# Epoch 129: 100%|██████████| 7/7 [00:01<00:00,  5.06it/s]
# -------------------
# epoch 128 || Epoch_D_loss:0.1337 ||Epoch_G_loss:0.0585
# timer: 1.3862 sec.
# -------------------
# Epoch 129/170
# -------------------
#  (train)
# Epoch 130: 100%|██████████| 7/7 [00:01<00:00,  5.10it/s]
# -------------------
# epoch 129 || Epoch_D_loss:0.1401 ||Epoch_G_loss:0.0705
# timer: 1.3769 sec.
# -------------------
# Epoch 130/170
# -------------------
#  (train)
# Epoch 131: 100%|██████████| 7/7 [00:01<00:00,  5.15it/s]
# -------------------
# epoch 130 || Epoch_D_loss:0.1412 ||Epoch_G_loss:0.0542
# timer: 1.3629 sec.
# -------------------
# Epoch 131/170
# -------------------
#  (train)
# Epoch 132: 100%|██████████| 7/7 [00:01<00:00,  5.18it/s]
# -------------------
# epoch 131 || Epoch_D_loss:0.1231 ||Epoch_G_loss:0.0940
# timer: 1.3558 sec.
# -------------------
# Epoch 132/170
# -------------------
#  (train)
# Epoch 133: 100%|██████████| 7/7 [00:01<00:00,  5.22it/s]
# -------------------
# epoch 132 || Epoch_D_loss:0.1446 ||Epoch_G_loss:0.0370
# timer: 1.3454 sec.
# -------------------
# Epoch 133/170
# -------------------
#  (train)
# Epoch 134: 100%|██████████| 7/7 [00:01<00:00,  5.24it/s]
# -------------------
# epoch 133 || Epoch_D_loss:0.1422 ||Epoch_G_loss:0.0750
# timer: 1.3385 sec.
# -------------------
# Epoch 134/170
# -------------------
#  (train)
# Epoch 135: 100%|██████████| 7/7 [00:01<00:00,  5.21it/s]
# -------------------
# epoch 134 || Epoch_D_loss:0.1258 ||Epoch_G_loss:0.0607
# timer: 1.3475 sec.
# -------------------
# Epoch 135/170
# -------------------
#  (train)
# Epoch 136: 100%|██████████| 7/7 [00:01<00:00,  5.22it/s]
# -------------------
# epoch 135 || Epoch_D_loss:0.1261 ||Epoch_G_loss:0.0877
# timer: 1.3440 sec.
# -------------------
# Epoch 136/170
# -------------------
#  (train)
# Epoch 137: 100%|██████████| 7/7 [00:01<00:00,  5.21it/s]
# -------------------
# epoch 136 || Epoch_D_loss:0.1315 ||Epoch_G_loss:0.0650
# timer: 1.3472 sec.
# -------------------
# Epoch 137/170
# -------------------
#  (train)
# Epoch 138: 100%|██████████| 7/7 [00:01<00:00,  5.29it/s]
# -------------------
# epoch 137 || Epoch_D_loss:0.1344 ||Epoch_G_loss:0.0792
# timer: 1.3268 sec.
# -------------------
# Epoch 138/170
# -------------------
#  (train)
# Epoch 139: 100%|██████████| 7/7 [00:01<00:00,  5.31it/s]
# -------------------
# epoch 138 || Epoch_D_loss:0.1342 ||Epoch_G_loss:0.0705
# timer: 1.3215 sec.
# -------------------
# Epoch 139/170
# -------------------
#  (train)
# Epoch 140: 100%|██████████| 7/7 [00:01<00:00,  5.34it/s]
# -------------------
# epoch 139 || Epoch_D_loss:0.1315 ||Epoch_G_loss:0.0732
# timer: 1.3142 sec.
# -------------------
# Epoch 140/170
# -------------------
#  (train)
# Epoch 141: 100%|██████████| 7/7 [00:01<00:00,  5.36it/s]
# -------------------
# epoch 140 || Epoch_D_loss:0.1278 ||Epoch_G_loss:0.0544
# timer: 1.3089 sec.
# -------------------
# Epoch 141/170
# -------------------
#  (train)
# Epoch 142: 100%|██████████| 7/7 [00:01<00:00,  5.33it/s]
# -------------------
# epoch 141 || Epoch_D_loss:0.1343 ||Epoch_G_loss:0.0705
# timer: 1.3158 sec.
# -------------------
# Epoch 142/170
# -------------------
#  (train)
# Epoch 143: 100%|██████████| 7/7 [00:01<00:00,  5.32it/s]
# -------------------
# epoch 142 || Epoch_D_loss:0.1298 ||Epoch_G_loss:0.0712
# timer: 1.3195 sec.
# -------------------
# Epoch 143/170
# -------------------
#  (train)
# Epoch 144: 100%|██████████| 7/7 [00:01<00:00,  5.34it/s]
# -------------------
# epoch 143 || Epoch_D_loss:0.1211 ||Epoch_G_loss:0.0946
# timer: 1.3138 sec.
# -------------------
# Epoch 144/170
# -------------------
#  (train)
# Epoch 145: 100%|██████████| 7/7 [00:01<00:00,  5.34it/s]
# -------------------
# epoch 144 || Epoch_D_loss:0.1352 ||Epoch_G_loss:0.0652
# timer: 1.3139 sec.
# -------------------
# Epoch 145/170
# -------------------
#  (train)
# Epoch 146: 100%|██████████| 7/7 [00:01<00:00,  5.38it/s]
# -------------------
# epoch 145 || Epoch_D_loss:0.1144 ||Epoch_G_loss:0.0921
# timer: 1.3045 sec.
# -------------------
# Epoch 146/170
# -------------------
#  (train)
# Epoch 147: 100%|██████████| 7/7 [00:01<00:00,  5.38it/s]
# -------------------
# epoch 146 || Epoch_D_loss:0.1281 ||Epoch_G_loss:0.0740
# timer: 1.3062 sec.
# -------------------
# Epoch 147/170
# -------------------
#  (train)
# Epoch 148: 100%|██████████| 7/7 [00:01<00:00,  5.38it/s]
# -------------------
# epoch 147 || Epoch_D_loss:0.1222 ||Epoch_G_loss:0.0722
# timer: 1.3055 sec.
# -------------------
# Epoch 148/170
# -------------------
#  (train)
# Epoch 149: 100%|██████████| 7/7 [00:01<00:00,  5.42it/s]
# -------------------
# epoch 148 || Epoch_D_loss:0.1217 ||Epoch_G_loss:0.0765
# timer: 1.2943 sec.
# -------------------
# Epoch 149/170
# -------------------
#  (train)
# Epoch 150: 100%|██████████| 7/7 [00:01<00:00,  5.45it/s]
# -------------------
# epoch 149 || Epoch_D_loss:0.1282 ||Epoch_G_loss:0.0983
# timer: 1.2891 sec.
# -------------------
# Epoch 150/170
# -------------------
#  (train)
# Epoch 151: 100%|██████████| 7/7 [00:01<00:00,  5.44it/s]
# -------------------
# epoch 150 || Epoch_D_loss:0.1228 ||Epoch_G_loss:0.0697
# timer: 1.2890 sec.
# -------------------
# Epoch 151/170
# -------------------
#  (train)
# Epoch 152: 100%|██████████| 7/7 [00:01<00:00,  5.45it/s]
# -------------------
# epoch 151 || Epoch_D_loss:0.1171 ||Epoch_G_loss:0.0824
# timer: 1.2876 sec.
# -------------------
# Epoch 152/170
# -------------------
#  (train)
# Epoch 153: 100%|██████████| 7/7 [00:01<00:00,  5.47it/s]
# -------------------
# epoch 152 || Epoch_D_loss:0.1169 ||Epoch_G_loss:0.0769
# timer: 1.2818 sec.
# -------------------
# Epoch 153/170
# -------------------
#  (train)
# Epoch 154: 100%|██████████| 7/7 [00:01<00:00,  5.44it/s]
# -------------------
# epoch 153 || Epoch_D_loss:0.1218 ||Epoch_G_loss:0.0920
# timer: 1.2904 sec.
# -------------------
# Epoch 154/170
# -------------------
#  (train)
# Epoch 155: 100%|██████████| 7/7 [00:01<00:00,  5.46it/s]
# -------------------
# epoch 154 || Epoch_D_loss:0.1207 ||Epoch_G_loss:0.0590
# timer: 1.2849 sec.
# -------------------
# Epoch 155/170
# -------------------
#  (train)
# Epoch 156: 100%|██████████| 7/7 [00:01<00:00,  5.45it/s]
# -------------------
# epoch 155 || Epoch_D_loss:0.1266 ||Epoch_G_loss:0.0857
# timer: 1.2870 sec.
# -------------------
# Epoch 156/170
# -------------------
#  (train)
# Epoch 157: 100%|██████████| 7/7 [00:01<00:00,  5.48it/s]
# -------------------
# epoch 156 || Epoch_D_loss:0.1159 ||Epoch_G_loss:0.0891
# timer: 1.2802 sec.
# -------------------
# Epoch 157/170
# -------------------
#  (train)
# Epoch 158: 100%|██████████| 7/7 [00:01<00:00,  5.45it/s]
# -------------------
# epoch 157 || Epoch_D_loss:0.1089 ||Epoch_G_loss:0.0879
# timer: 1.2881 sec.
# -------------------
# Epoch 158/170
# -------------------
#  (train)
# Epoch 159: 100%|██████████| 7/7 [00:01<00:00,  5.46it/s]
# -------------------
# epoch 158 || Epoch_D_loss:0.1193 ||Epoch_G_loss:0.0672
# timer: 1.2863 sec.
# -------------------
# Epoch 159/170
# -------------------
#  (train)
# Epoch 160: 100%|██████████| 7/7 [00:01<00:00,  5.41it/s]
# -------------------
# epoch 159 || Epoch_D_loss:0.1128 ||Epoch_G_loss:0.0782
# timer: 1.2966 sec.
# -------------------
# Epoch 160/170
# -------------------
#  (train)
# Epoch 161: 100%|██████████| 7/7 [00:01<00:00,  5.46it/s]
# -------------------
# epoch 160 || Epoch_D_loss:0.1095 ||Epoch_G_loss:0.0861
# timer: 1.2857 sec.
# -------------------
# Epoch 161/170
# -------------------
#  (train)
# Epoch 162: 100%|██████████| 7/7 [00:01<00:00,  5.45it/s]
# -------------------
# epoch 161 || Epoch_D_loss:0.1163 ||Epoch_G_loss:0.0843
# timer: 1.2868 sec.
# -------------------
# Epoch 162/170
# -------------------
#  (train)
# Epoch 163: 100%|██████████| 7/7 [00:01<00:00,  5.39it/s]
# -------------------
# epoch 162 || Epoch_D_loss:0.1091 ||Epoch_G_loss:0.0916
# timer: 1.3029 sec.
# -------------------
# Epoch 163/170
# -------------------
#  (train)
# Epoch 164: 100%|██████████| 7/7 [00:01<00:00,  5.46it/s]
# -------------------
# epoch 163 || Epoch_D_loss:0.1068 ||Epoch_G_loss:0.1031
# timer: 1.2854 sec.
# -------------------
# Epoch 164/170
# -------------------
#  (train)
# Epoch 165: 100%|██████████| 7/7 [00:01<00:00,  5.40it/s]
# -------------------
# epoch 164 || Epoch_D_loss:0.1023 ||Epoch_G_loss:0.0776
# timer: 1.2983 sec.
# -------------------
# Epoch 165/170
# -------------------
#  (train)
# Epoch 166: 100%|██████████| 7/7 [00:01<00:00,  5.44it/s]
# -------------------
# epoch 165 || Epoch_D_loss:0.1182 ||Epoch_G_loss:0.0979
# timer: 1.2888 sec.
# -------------------
# Epoch 166/170
# -------------------
#  (train)
# Epoch 167: 100%|██████████| 7/7 [00:01<00:00,  5.40it/s]
# -------------------
# epoch 166 || Epoch_D_loss:0.1040 ||Epoch_G_loss:0.0697
# timer: 1.3005 sec.
# -------------------
# Epoch 167/170
# -------------------
#  (train)
# Epoch 168: 100%|██████████| 7/7 [00:01<00:00,  5.41it/s]
# -------------------
# epoch 167 || Epoch_D_loss:0.1156 ||Epoch_G_loss:0.0919
# timer: 1.2968 sec.
# -------------------
# Epoch 168/170
# -------------------
#  (train)
# Epoch 169: 100%|██████████| 7/7 [00:01<00:00,  5.39it/s]
# -------------------
# epoch 168 || Epoch_D_loss:0.0995 ||Epoch_G_loss:0.0921
# timer: 1.3005 sec.
# -------------------
# Epoch 169/170
# -------------------
#  (train)
# Epoch 170: 100%|██████████| 7/7 [00:01<00:00,  5.40it/s]
# -------------------
# epoch 169 || Epoch_D_loss:0.1067 ||Epoch_G_loss:0.0974
# timer: 1.2979 sec.

# %% [markdown]
# # Mode Collapse occurred!

# %% [markdown]
# ![modeCollapse.jpg](attachment:c9489418-0f82-4029-a6ce-af5aecfcecae.jpg)

# %% [markdown]
# While generating images, I encountered a problem known as *Mode Collapse*.
#
# This occurs when the generator succeeds in fooling the discriminator by repeatedly generating similar-looking images, and ends up producing only those limited patterns.
#
# To address this issue, I tried;
# * resetting the training environment (e.g., switching the computer device)
# * initializing the network (using `weights_init` function),
# * tuning hyperparameters such as the learning rate, batch size, and number of training epochs.

# %%
# Visualizing generated images

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# generaitng random numbers for input
batch_size = 8
z_dim = 20
fixed_z = torch.randn(batch_size, z_dim)
fixed_z = fixed_z.view(fixed_z.size(0), fixed_z.size(1), 1, 1)

# generating image
G_update.eval()
fake_images, am1, am2 = G_update(fixed_z.to(device))

# training data
batch_iterator = iter(train_dataloader) # transform to iterator
images = next(batch_iterator) # extracting the first element

# output
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # show train image in upper row
    plt.subplot(2, 5, i+1)
    plt.imshow(images[i][0].cpu().detach().numpy(), 'gray')

    # show generated image in lower row
    plt.subplot(2, 5, 5+i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

# %% [markdown]
# The top row shows training images, and the bottom row shows generated images.

# %%
# output an attention map
fig = plt.figure(figsize=(15, 6))
for i in range(0, 5):
    # show generated image in upper row
    plt.subplot(2, 5, i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')

    # show attention map pixel data in lower row
    plt.subplot(2, 5, 5+i+1)
    am = am1[i].view(16, 16, 16, 16)
    am = am[7][7]  # A pixel at 7th row and 7th column
    plt.imshow(am.cpu().detach().numpy(), 'Reds')

# %% [markdown]
# # Attention Map
# The attention map shows how the pixel at position (7,7) -- which acts as the **query** -- attends to all other pixels in the 16x16 feature map.
#
# Pixels that are attended to are shown in **red**, while those that are not are shown in **white**.
#
# (All other pixels serves as **keys** corresponding to their values.)
#
# Now, let's try changing the query location.
#
# For example, let's take the pixel at position (7,7) and the pixel at position (5,12) as separate queries, and compute their respective attention maps by displaying them stacked vertically.

# %%
# output two attention maps with different query positions
fig = plt.figure(figsize=(15, 9))

for i in range(5):
    # show generated image (same for both attention maps)
    plt.subplot(3, 5, i+1)
    plt.imshow(fake_images[i][0].cpu().detach().numpy(), 'gray')
    plt.axis('off')
    if i == 0:
        plt.title("Generated Image")

    # Attention map for query at (7, 7)
    plt.subplot(3, 5, 5 + i + 1)
    am = am1[i].view(16, 16, 16, 16)
    am_7_7 = am[7][7]
    plt.imshow(am_7_7.cpu().detach().numpy(), 'Reds')
    plt.axis('off')
    if i == 0:
        plt.title("Attention @ (7, 7)")

    # Attention map for query at (5, 12)
    plt.subplot(3, 5, 10 + i + 1)
    am_5_12 = am[5][12]
    plt.imshow(am_5_12.cpu().detach().numpy(), 'Reds')
    plt.axis('off')
    if i == 0:
        plt.title("Attention @ (5, 12)")

plt.tight_layout()
plt.show()

# %% [markdown]
# Each pixel has its own unique attention map, which indicates that it builds independent relationships with other pixels.
#
# As training progresses and the number of epochs increases, the attention maps tend to become almost entirely white.
#
# This could be interpreted as the model no longer focusing on its attention on specific pixels once a certain level of learning has achieved.

# %% [markdown]
# # Conclusion
#
# DCGAN generates images by capturing local features through transposed convolution.
#
# However, this approach has a limitation: when local features are simply enlarged, it becomes difficult for the model to capture the global structure of the image.
#
# SAGAN addresses this issue by incorporating the attention mechanism, allowing each pixel to attend to the entire image during generation.
#
# Although Mode Collapse is a challenging problem, it can be mitigated by using Spectral Normalization to stabilize the update of weight parameters, along with fine-tuning of hyperparameters such as learning rate and batch-size by the programmer.
#
# Thank you for reading!

# %% [markdown]
# # Resources
#
# **PyTorchによる発展ディープラーニング**
# (Advanced Deep Learning with PyTorch, in Japanese)
# Yuutaro Ogawa, 2019
#
# **ディープラーニングを支える技術2**
# (Techniques Underpinning Deep Learning, vol.2, in Japanese)
# Daisuke Okanohara, 2022
